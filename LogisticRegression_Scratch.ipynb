# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df1 = pd.read_csv("ex2data1.txt")

# %%
df1.head()
# Out:
#    34.62365962451697  78.0246928153624  0
# 0          30.286711         43.894998  0
# 1          35.847409         72.902198  0
# 2          60.182599         86.308552  1
# 3          79.032736         75.344376  1
# 4          45.083277         56.316372  0

# %%
df1.rename(columns={'34.62365962451697': 'exam1', '78.0246928153624': 'exam2','0':'y'}, inplace=True)

# %%
df1
# Out:
#         exam1      exam2  y
# 0   30.286711  43.894998  0
# 1   35.847409  72.902198  0
# 2   60.182599  86.308552  1
# 3   79.032736  75.344376  1
# 4   45.083277  56.316372  0
# ..        ...        ... ..
# 94  83.489163  48.380286  1
# 95  42.261701  87.103851  1
# 96  99.315009  68.775409  1
# 97  55.340018  64.931938  1
# 98  74.775893  89.529813  1
#
# [99 rows x 3 columns]

# %%
plt.scatter(df1['exam1'][(df1.y == 0) | (df1.y == 0)],
            df1['exam2'][(df1.y == 0) | (df1.y == 0)],
           marker='D',
           color='red',
           label='not admitted')
plt.scatter(df1['exam1'][(df1.y == 1) | (df1.y == 1)],
            df1['exam2'][(df1.y == 1) | (df1.y == 1)],
           marker='x',
           color='blue',
           label='admitted')

plt.xlabel('exam1')
plt.ylabel('exam2')
plt.legend()
plt.show()

# %%
def sigmoid(x):
    res = 1/(1+np.exp(-x))
    return res

# %%
#from sklearn.model_selection import train_test_split
#train, test = train_test_split(df1, test_size=0.2)
score1 = df1[["exam1","exam2"]]

output = df1['y']
ones = np.ones([score1.shape[0], 1]) 
score1 = np.concatenate([ones, score1], 1)
weights = np.zeros(score1.shape[1])

# %%
def cost(theta, x, y):
    m = x.shape[0]
    return - (1 / m) * np.sum(y * np.log(sigmoid(product(theta,x))) + (1 - y) * np.log(1 - sigmoid(product(theta,x))))

# %%
def product(weights,x):
    return np.dot(x, weights)

# %%
def diff(weights,x,y):
    pred = []
    for i in y:
        pred.append(i)
        m = x.shape[0]
    return (1 / m) * np.dot(x.T, sigmoid(product(weights, x)) - pred)

def LogisticRegression(X,Y,lr,iterations,weights):
    m = X.shape[0]
    limit = 0.25
    costval = 10
    costlist = []
    costlist.append(costval)
    iterations = 0
    while costval > limit:                       
        costval = cost(weights,X,Y)                   
        diffval = diff(weights,X,Y)                  
        weights = weights - (lr*diffval)                     
        if iterations%100==0:                  
            print(cost)
            costlist.append(costval)
        iterations = iterations + 1                  
      

    return weights, costval, costlist

# %%
lr = 0.001
iterations = 1000
weights, costs, costlist = LogisticRegression(score1,output,lr,iterations,weights)
# Out:
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# <function cost at 0x7fa301dc0c20>
# ...

# %%
print(costs)
print(weights)
plt.plot(costlist)
# Out:
# 0.2499999593163946
# [-11.90781197   0.09967504   0.09565425]

# %%
x_values = np.array([np.min(score1[:, 1]) - 2, np.max(score1[:, 1] + 2)])
y_values = -(weights[0] + (weights[1] * x_values)) / weights[2]
print(x_values)
print(y_values)
print((weights[1] * x_values))

plt.plot(x_values, y_values, label='Decision Boundary')
plt.scatter(df1['exam1'][(df1.y == 0) | (df1.y == 0)],
            df1['exam2'][(df1.y == 0) | (df1.y == 0)],
           marker='D',
           color='red',
           label='not admitted')
plt.scatter(df1['exam1'][(df1.y == 1) | (df1.y == 1)],
            df1['exam2'][(df1.y == 1) | (df1.y == 1)],
           marker='x',
           color='blue',
           label='admitted')

plt.xlabel('exam1')
plt.ylabel('exam2')
plt.legend()
plt.show()
# Out:
# [ 28.05882245 101.8278578 ]
# [95.24979448 18.37990982]
# [ 2.79676415 10.14969545]

# %%
#evaluating probability
probability = weights[0] + (weights[1]*45) + (weights[2]*85)
x = sigmoid(probability)
print(x)
# Out:
# 0.6699980130244401
